# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt

# %%
url = "https://api.github.com/search/repositories?q=machine+learning&sort=stars&order=desc&per_page=100"
response = requests.get(url)
data = response.json()
print(response.status_code)
# Out:
# 200

# %%
df = pd.DataFrame(data['items'])
df.head()
# Out:
#           id                           node_id                      name  \
# 0   45717250  MDEwOlJlcG9zaXRvcnk0NTcxNzI1MA==                tensorflow
# 1  155220641  MDEwOlJlcG9zaXRvcnkxNTUyMjA2NDE=              transformers
# 2  343965132  MDEwOlJlcG9zaXRvcnkzNDM5NjUxMzI=          ML-For-Beginners
# 3  145553672  MDEwOlJlcG9zaXRvcnkxNDU1NTM2NzI=                    funNLP
# 4   21872392  MDEwOlJlcG9zaXRvcnkyMTg3MjM5Mg==  awesome-machine-learning
#
#                                full_name  private  \
# 0                  tensorflow/tensorflow    False
# 1               huggingface/transformers    False
# 2             microsoft/ML-For-Beginners    False
# 3                  fighting41love/funNLP    False
# 4  josephmisiti/awesome-machine-learning    False
#
#                                                owner  \
# 0  {'login': 'tensorflow', 'id': 15658638, 'node_...
# 1  {'login': 'huggingface', 'id': 25720743, 'node...
# 2  {'login': 'microsoft', 'id': 6154722, 'node_id...
# 3  {'login': 'fighting41love', 'id': 11475294, 'n...
# 4  {'login': 'josephmisiti', 'id': 246302, 'node_...
#
#                                             html_url  \
# 0           https://github.com/tensorflow/tensorflow
# 1        https://github.com/huggingface/transformers
# 2      https://github.com/microsoft/ML-For-Beginners
# 3           https://github.com/fighting41love/funNLP
# 4  https://github.com/josephmisiti/awesome-machin...
#
#                                          description   fork  \
# 0  An Open Source Machine Learning Framework for ...  False
# 1  🤗 Transformers: the model-definition framework...  False
# 2  12 weeks, 26 lessons, 52 quizzes, classic Mach...  False
# 3  中英文敏感词、语言检测、中外手机/电话归属地/运营商查询、名字推断性别、手机号抽取、身份证抽...  False
# 4  A curated list of awesome Machine Learning fra...  False
#
#                                                  url  ...  \
# 0  https://api.github.com/repos/tensorflow/tensor...  ...
# 1  https://api.github.com/repos/huggingface/trans...  ...
# 2  https://api.github.com/repos/microsoft/ML-For-...  ...
# 3  https://api.github.com/repos/fighting41love/fu...  ...
# 4  https://api.github.com/repos/josephmisiti/awes...  ...
#
#   web_commit_signoff_required has_pull_requests pull_request_creation_policy  \
# 0                       False              True                          all
# 1                       False              True                          all
# 2                       False              True                          all
# 3                       False              True                          all
# 4                       False              True                          all
#
#                                               topics visibility  forks  \
# 0  [deep-learning, deep-neural-networks, distribu...     public  76128
# 1  [audio, deep-learning, deepseek, gemma, glm, h...     public  34360
# 2  [data-science, education, machine-learning, ma...     public  22075
# 3                                                 []     public  15275
# 4                                                 []     public  15626
#
#   open_issues watchers default_branch score
# 0        2932   197626         master   1.0
# 1        2406   164432           main   1.0
# 2          13    89792           main   1.0
# 3          52    82664         master   1.0
# 4          27    74149         master   1.0
#
# [5 rows x 82 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 82 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            100 non-null    int64
#  1   node_id                       100 non-null    object
#  2   name                          100 non-null    object
#  3   full_name                     100 non-null    object
#  4   private                       100 non-null    bool
#  5   owner                         100 non-null    object
#  6   html_url                      100 non-null    object
#  7   description                   100 non-null    object
#  8   fork                          100 non-null    bool
#  9   url                           100 non-null    object
#  10  forks_url                     100 non-null    object
#  11  keys_url                      100 non-null    object
#  12  collaborators_url             100 non-null    object
#  13  teams_url                     100 non-null    object
#  14  hooks_url                     100 non-null    object
#  15  issue_events_url              100 non-null    object
#  16  events_url                    100 non-null    object
#  17  assignees_url                 100 non-null    object
#  18  branches_url                  100 non-null    object
#  19  tags_url                      100 non-null    object
#  20  blobs_url                     100 non-null    object
#  21  git_tags_url                  100 non-null    object
#  22  git_refs_url                  100 non-null    object
#  23  trees_url                     100 non-null    object
#  24  statuses_url                  100 non-null    object
#  25  languages_url                 100 non-null    object
#  26  stargazers_url                100 non-null    object
#  27  contributors_url              100 non-null    object
#  28  subscribers_url               100 non-null    object
#  29  subscription_url              100 non-null    object
#  30  commits_url                   100 non-null    object
#  31  git_commits_url               100 non-null    object
#  32  comments_url                  100 non-null    object
#  33  issue_comment_url             100 non-null    object
#  34  contents_url                  100 non-null    object
#  35  compare_url                   100 non-null    object
#  36  merges_url                    100 non-null    object
#  37  archive_url                   100 non-null    object
#  38  downloads_url                 100 non-null    object
#  39  issues_url                    100 non-null    object
#  40  pulls_url                     100 non-null    object
#  41  milestones_url                100 non-null    object
#  42  notifications_url             100 non-null    object
#  43  labels_url                    100 non-null    object
#  44  releases_url                  100 non-null    object
#  45  deployments_url               100 non-null    object
#  46  created_at                    100 non-null    object
#  47  updated_at                    100 non-null    object
#  48  pushed_at                     100 non-null    object
#  49  git_url                       100 non-null    object
#  50  ssh_url                       100 non-null    object
#  51  clone_url                     100 non-null    object
#  52  svn_url                       100 non-null    object
#  53  homepage                      92 non-null     object
#  54  size                          100 non-null    int64
#  55  stargazers_count              100 non-null    int64
#  56  watchers_count                100 non-null    int64
#  57  language                      77 non-null     object
#  58  has_issues                    100 non-null    bool
#  59  has_projects                  100 non-null    bool
#  60  has_downloads                 100 non-null    bool
#  61  has_wiki                      100 non-null    bool
#  62  has_pages                     100 non-null    bool
#  63  has_discussions               100 non-null    bool
#  64  forks_count                   100 non-null    int64
#  65  mirror_url                    0 non-null      object
#  66  archived                      100 non-null    bool
#  67  disabled                      100 non-null    bool
#  68  open_issues_count             100 non-null    int64
#  69  license                       78 non-null     object
#  70  allow_forking                 100 non-null    bool
#  71  is_template                   100 non-null    bool
#  72  web_commit_signoff_required   100 non-null    bool
#  73  has_pull_requests             100 non-null    bool
#  74  pull_request_creation_policy  100 non-null    object
#  75  topics                        100 non-null    object
#  76  visibility                    100 non-null    object
#  77  forks                         100 non-null    int64
#  78  open_issues                   100 non-null    int64
#  79  watchers                      100 non-null    int64
#  80  default_branch                100 non-null    object
#  81  score                         100 non-null    float64
# dtypes: bool(14), float64(1), int64(9), object(58)
# memory usage: 54.6+ KB

# %%
df.shape
# Out:
# (100, 82)

# %%
columns = ['name', 'owner', 'language', 'stargazers_count',
'forks_count', 'watchers_count', 'open_issues_count',
'created_at', 'updated_at', 'license']

df = df[columns]

# %%
df.head()
# Out:
#                        name  \
# 0                tensorflow
# 1              transformers
# 2          ML-For-Beginners
# 3                    funNLP
# 4  awesome-machine-learning
#
#                                                owner          language  \
# 0  {'login': 'tensorflow', 'id': 15658638, 'node_...               C++
# 1  {'login': 'huggingface', 'id': 25720743, 'node...            Python
# 2  {'login': 'microsoft', 'id': 6154722, 'node_id...  Jupyter Notebook
# 3  {'login': 'fighting41love', 'id': 11475294, 'n...            Python
# 4  {'login': 'josephmisiti', 'id': 246302, 'node_...            Python
#
#    stargazers_count  forks_count  watchers_count  open_issues_count  \
# 0            197626        76128          197626               2932
# 1            164432        34360          164432               2406
# 2             89792        22075           89792                 13
# 3             82664        15275           82664                 52
# 4             74149        15626           74149                 27
#
#              created_at            updated_at  \
# 0  2015-11-07T01:19:20Z  2026-08-25T16:18:28Z
# 1  2018-10-29T13:56:00Z  2026-08-25T16:29:28Z
# 2  2021-03-03T01:34:05Z  2026-08-25T16:02:31Z
# 3  2018-08-21T11:20:39Z  2026-08-25T16:16:53Z
# 4  2014-07-15T19:11:19Z  2026-08-25T13:52:55Z
#
#                                              license
# 0  {'key': 'apache-2.0', 'name': 'Apache License ...
# 1  {'key': 'apache-2.0', 'name': 'Apache License ...
# 2  {'key': 'mit', 'name': 'MIT License', 'spdx_id...
# 3                                               None
# 4  {'key': 'other', 'name': 'Other', 'spdx_id': '...

# %%
owner_list = []
for item in df["owner"]:
    if type(item) == dict and "login" in item:
        owner_list.append(item["login"])
    else:
        owner_list.append("Unknown")
df["owner"] = owner_list

license_list = []
for item in df["license"]:
    if type(item) == dict and "name" in item:
        license_list.append(item["name"])
    else:
        license_list.append("None")
df["license"] = license_list

# %%
print(df.isnull().sum())
# Out:
# name                  0
# owner                 0
# language             23
# stargazers_count      0
# forks_count           0
# watchers_count        0
# open_issues_count     0
# created_at            0
# updated_at            0
# license               0
# dtype: int64

# %%
df['language'] = df['language'].fillna('Unknown')

# %%
print(df.isnull().sum())
# Out:
# name                 0
# owner                0
# language             0
# stargazers_count     0
# forks_count          0
# watchers_count       0
# open_issues_count    0
# created_at           0
# updated_at           0
# license              0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['created_at'] = pd.to_datetime(df['created_at']).dt.date

# %%
df['updated_at'] = pd.to_datetime(df['updated_at']).dt.date

# %%
df = df.rename(columns={
    'stargazers_count': 'stars',
    'forks_count': 'forks',
    'watchers_count': 'watchers',
    'open_issues_count': 'open_issues',
    'created_at': 'created_date',
    'updated_at': 'updated_date'
})

# %%
df.head()
# Out:
#                        name           owner          language   stars  forks  \
# 0                tensorflow      tensorflow               C++  197626  76128
# 1              transformers     huggingface            Python  164432  34360
# 2          ML-For-Beginners       microsoft  Jupyter Notebook   89792  22075
# 3                    funNLP  fighting41love            Python   82664  15275
# 4  awesome-machine-learning    josephmisiti            Python   74149  15626
#
#    watchers  open_issues created_date updated_date             license
# 0    197626         2932   2015-11-07   2026-08-25  Apache License 2.0
# 1    164432         2406   2018-10-29   2026-08-25  Apache License 2.0
# 2     89792           13   2021-03-03   2026-08-25         MIT License
# 3     82664           52   2018-08-21   2026-08-25                None
# 4     74149           27   2014-07-15   2026-08-25               Other

# %%
df.to_csv('github_projects.csv', index=False)

# %%
check_df = pd.read_csv('github_projects.csv')
check_df.head()
check_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          100 non-null    object
#  1   owner         100 non-null    object
#  2   language      100 non-null    object
#  3   stars         100 non-null    int64
#  4   forks         100 non-null    int64
#  5   watchers      100 non-null    int64
#  6   open_issues   100 non-null    int64
#  7   created_date  100 non-null    object
#  8   updated_date  100 non-null    object
#  9   license       78 non-null     object
# dtypes: int64(4), object(6)
# memory usage: 7.9+ KB

# %% [markdown]
# # **Task 2**

# %%
import sqlite3

# %%
conn = sqlite3.connect('github_projects.db')
df = pd.read_csv('github_projects.csv')
df.to_sql('Repositories', conn, if_exists='replace', index=False)
pd.read_sql("SELECT * FROM Repositories LIMIT 5;", conn)
# Out:
#                        name           owner          language   stars  forks  \
# 0                tensorflow      tensorflow               C++  197626  76128
# 1              transformers     huggingface            Python  164432  34360
# 2          ML-For-Beginners       microsoft  Jupyter Notebook   89792  22075
# 3                    funNLP  fighting41love            Python   82664  15275
# 4  awesome-machine-learning    josephmisiti            Python   74149  15626
#
#    watchers  open_issues created_date updated_date             license
# 0    197626         2932   2015-11-07   2026-08-25  Apache License 2.0
# 1    164432         2406   2018-10-29   2026-08-25  Apache License 2.0
# 2     89792           13   2021-03-03   2026-08-25         MIT License
# 3     82664           52   2018-08-21   2026-08-25                None
# 4     74149           27   2014-07-15   2026-08-25               Other

# %%
stars = "SELECT * FROM Repositories WHERE stars > 10000;"
pd.read_sql(stars, conn)
# Out:
#                                name           owner          language   stars  \
# 0                        tensorflow      tensorflow               C++  197626
# 1                      transformers     huggingface            Python  164432
# 2                  ML-For-Beginners       microsoft  Jupyter Notebook   89792
# 3                            funNLP  fighting41love            Python   82664
# 4          awesome-machine-learning    josephmisiti            Python   74149
# ..                              ...             ...               ...     ...
# 65  machine-learning-systems-design       chiphuyen              HTML   10551
# 66                 Machine-Learning    Jack-Cherish            Python   10376
# 67           machine-learning-notes      roboticcam  Jupyter Notebook   10342
# 68              3D-Machine-Learning     timzhang642           Unknown   10192
# 69                             tpot    EpistasisLab  Jupyter Notebook   10052
#
#     forks  watchers  open_issues created_date updated_date  \
# 0   76128    197626         2932   2015-11-07   2026-08-25
# 1   34360    164432         2406   2018-10-29   2026-08-25
# 2   22075     89792           13   2021-03-03   2026-08-25
# 3   15275     82664           52   2018-08-21   2026-08-25
# 4   15626     74149           27   2014-07-15   2026-08-25
# ..    ...       ...          ...          ...          ...
# 65   1634     10551           11   2019-11-24   2026-08-25
# 66   5064     10376            7   2017-03-25   2026-08-25
# 67   1826     10342           28   2018-02-15   2026-08-25
# 68   1798     10192           21   2017-08-12   2026-08-25
# 69   1563     10052          312   2015-11-03   2026-08-24
#
#                                    license
# 0                       Apache License 2.0
# 1                       Apache License 2.0
# 2                              MIT License
# 3                                     None
# 4                                    Other
# ..                                     ...
# 65                                    None
# 66                                    None
# 67                                    None
# 68                                    None
# 69  GNU Lesser General Public License v3.0
#
# [70 rows x 10 columns]

# %%
machine = "SELECT * FROM Repositories WHERE name LIKE '%Machine%';"
pd.read_sql(machine, conn)
# Out:
#                                                  name  \
# 0                            awesome-machine-learning
# 1   500-AI-Machine-learning-Deep-learning-Computer...
# 2             machine-learning-for-software-engineers
# 3                           homemade-machine-learning
# 4                 awesome-production-machine-learning
# 5                        machine-learning-for-trading
# 6                    stanford-cs-229-machine-learning
# 7                          Machine-Learning-Tutorials
# 8                           machine-learning-zoomcamp
# 9                          machine-learning-interview
# 10                       python-machine-learning-book
# 11                         dive-into-machine-learning
# 12                    machine-learning-systems-design
# 13                                   Machine-Learning
# 14                             machine-learning-notes
# 15                                3D-Machine-Learning
# 16                                    machinelearning
# 17                          machine_learning_examples
# 18  state-of-the-art-result-for-machine-learning-p...
# 19                         financial-machine-learning
# 20                                    machinelearning
# 21                             MachineLearning_Python
# 22                        Machine-Learning-Collection
# 23                       machine-learning-cheat-sheet
# 24                           machine-learning-roadmap
# 25                       machine-learning-yearning-cn
# 26           Machine-Learning-Specialization-Coursera
# 27                    Machine-learning-learning-notes
# 28                 Learn_Machine_Learning_in_3_Months
# 29                          industry-machine-learning
#
#                          owner          language  stars  forks  watchers  \
# 0                 josephmisiti            Python  74149  15626     74149
# 1                ashishpatel26           Unknown  36533   7467     36533
# 2                      ZuzooVn           Unknown  28866   6147     28866
# 3                     trekhleb  Jupyter Notebook  24778   4193     24778
# 4                    EthicalML           Unknown  20867   2591     20867
# 5                stefan-jansen  Jupyter Notebook  20636   5562     20636
# 6                     afshinea           Unknown  20158   4254     20158
# 7                   ujjwalkarn           Unknown  18140   3969     18140
# 8                DataTalksClub  Jupyter Notebook  14021   3107     14021
# 9                     khangich           Unknown  12795   2045     12795
# 10                       rasbt  Jupyter Notebook  12643   4373     12643
# 11  dive-into-machine-learning           Unknown  11390   1866     11390
# 12                   chiphuyen              HTML  10551   1634     10551
# 13                Jack-Cherish            Python  10376   5064     10376
# 14                  roboticcam  Jupyter Notebook  10342   1826     10342
# 15                 timzhang642           Unknown  10192   1798     10192
# 16                      dotnet                C#   9352   1950      9352
# 17              lazyprogrammer            Python   8915   6402      8915
# 18                  RedditSota           Unknown   8893   1293      8893
# 19                      firmai            Python   8760   1410      8760
# 20                      ljpzzz  Jupyter Notebook   8706   3686      8706
# 21                   lawlite19            Python   8584   2515      8584
# 22              aladdinpersson            Python   8489   2785      8489
# 23                 soulmachine               TeX   8046   1332      8046
# 24                   mrdbourke           Unknown   7894   1167      7894
# 25             deeplearning-ai               CSS   7845   1499      7845
# 26               greyhatguy007  Jupyter Notebook   7812   3728      7812
# 27                    Vay-keen           Unknown   7763   1879      7763
# 28                  llSourcell           Unknown   7601   2311      7601
# 29                      firmai  Jupyter Notebook   7485   1249      7485
#
#     open_issues created_date updated_date  \
# 0            27   2014-07-15   2026-08-25
# 1            68   2021-01-02   2026-08-25
# 2            32   2016-10-09   2026-08-25
# 3            30   2018-11-01   2026-08-25
# 4            31   2018-08-15   2026-08-25
# 5             7   2018-05-09   2026-08-25
# 6            20   2018-08-04   2026-08-25
# 7            47   2015-09-12   2026-08-25
# 8             3   2020-04-17   2026-08-25
# 9             9   2020-08-11   2026-08-25
# 10           13   2015-08-07   2026-08-24
# 11            0   2015-02-22   2026-08-20
# 12           11   2019-11-24   2026-08-25
# 13            7   2017-03-25   2026-08-25
# 14           28   2018-02-15   2026-08-25
# 15           21   2017-08-12   2026-08-25
# 16         1008   2018-05-03   2026-08-25
# 17           33   2014-07-31   2026-08-25
# 18           14   2017-11-09   2026-08-24
# 19           15   2019-03-21   2026-08-25
# 20           17   2016-05-12   2026-08-21
# 21           10   2016-10-17   2026-08-25
# 22          118   2020-03-26   2026-08-25
# 23           11   2013-05-09   2026-08-25
# 24           12   2020-07-09   2026-08-24
# 25            4   2018-06-19   2026-08-23
# 26           26   2022-06-16   2026-08-25
# 27           28   2018-03-24   2026-08-24
# 28           19   2018-03-02   2026-08-25
# 29            3   2019-05-03   2026-08-25
#
#                                               license
# 0                                               Other
# 1                                                None
# 2   Creative Commons Attribution Share Alike 4.0 I...
# 3                                         MIT License
# 4                                         MIT License
# 5                                         MIT License
# 6                                         MIT License
# 7                Creative Commons Zero v1.0 Universal
# 8                                                None
# 9                                                None
# 10                                        MIT License
# 11     Creative Commons Attribution 4.0 International
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                        MIT License
# 17                                               None
# 18                                 Apache License 2.0
# 19                                               None
# 20                                        MIT License
# 21                                        MIT License
# 22                                        MIT License
# 23                                               None
# 24                                        MIT License
# 25                                              Other
# 26                                        MIT License
# 27                                               None
# 28                                               None
# 29                                               None

# %%
pd.read_sql(
    "SELECT name, language, stars FROM Repositories WHERE language = 'Python' AND stars > 20000;",
    conn,
)
# Out:
#                                  name language   stars
# 0                        transformers   Python  164432
# 1                              funNLP   Python   82664
# 2            awesome-machine-learning   Python   74149
# 3                        scikit-learn   Python   67061
# 4                              gradio   Python   43417
# 5                     ML-From-Scratch   Python   32523
# 6  linkedin-skill-assessments-quizzes   Python   28808
# 7                         cs249r_book   Python   27999
# 8                                onnx   Python   21356
# 9                                rasa   Python   21305

# %%
pd.read_sql(
    "SELECT name, language FROM Repositories WHERE NOT language = 'Python';",
    conn,
)
# Out:
#                                                  name          language
# 0                                          tensorflow               C++
# 1                                    ML-For-Beginners  Jupyter Notebook
# 2   500-AI-Machine-learning-Deep-learning-Computer...           Unknown
# 3                                         C-Plus-Plus               C++
# 4                                              netron        JavaScript
# ..                                                ...               ...
# 65                    Machine-learning-learning-notes           Unknown
# 66                                  awesome-youtubers          Markdown
# 67                 Learn_Machine_Learning_in_3_Months           Unknown
# 68                                              h2o-3  Jupyter Notebook
# 69                          industry-machine-learning  Jupyter Notebook
#
# [70 rows x 2 columns]

# %%
pd.read_sql(
    "SELECT name, stars FROM Repositories ORDER BY stars DESC LIMIT 10;", conn
)
# Out:
#                                                 name   stars
# 0                                         tensorflow  197626
# 1                                       transformers  164432
# 2                                   ML-For-Beginners   89792
# 3                                             funNLP   82664
# 4                           awesome-machine-learning   74149
# 5                                       scikit-learn   67061
# 6                                             gradio   43417
# 7  500-AI-Machine-learning-Deep-learning-Computer...   36533
# 8                                        C-Plus-Plus   34603
# 9                                             netron   33399

# %%
pd.read_sql(
    "SELECT COUNT(*) AS total_repos, AVG(stars) AS avg_stars FROM Repositories;",
    conn,
)
# Out:
#    total_repos  avg_stars
# 0          100   20834.78

# %%
pd.read_sql(
    "SELECT language, COUNT(*) AS count FROM Repositories GROUP BY language HAVING count > 5;",
    conn,
)
# Out:
#            language  count
# 0               C++     12
# 1  Jupyter Notebook     19
# 2            Python     30
# 3           Unknown     23

# %%
top_10 = pd.read_sql(
    "SELECT name, stars FROM Repositories ORDER BY stars DESC LIMIT 10;", conn
)

# %%
lang_counts = pd.read_sql("SELECT language, COUNT(*) AS count FROM Repositories GROUP BY language HAVING count > 2;", conn)
plt.figure(figsize=(6, 6))
plt.pie(lang_counts['count'], labels=lang_counts['language'], autopct='%1.1f%%')
plt.title("Repositories by Language")
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.bar(top_10["name"], top_10["stars"])
plt.xlabel("repository name")
plt.ylabel("stars")
plt.title("top 10 repositories")
plt.xticks(rotation=45, ha="right")
plt.show()

# %%
check_df["year"] = pd.to_datetime(check_df["created_date"]).dt.year
trend = check_df.groupby("year").size()

plt.figure(figsize=(8, 4))
plt.plot(trend.index, trend.values, marker="o")
plt.xlabel("year")
plt.ylabel("number of repositories")
plt.title("repositories created per year")
plt.show()

# %% [markdown]
# # **Interpreting the results:**
# Most popular projects: Python projects like ***tensorflow*** and ***transformers*** are the most popular and have the highest number of stars.
#
# Creation trends: The creation of machine learning projects increased rapidly between ***2016 and 2018***.

# %% [markdown]
# # **Ethical Reflections**
#
# ***Question 1*** : Why is it important to verify data collected from public APIs?
#
# - To ensure data accuracy, up-to-dateness, and the absence of missing or corrupted fields before analysis begins.
#
# ***Question 2*** : Why should data analysts document their data sources?
#
# - To maintain transparency, build trust, and enable anyone to easily verify the figures or replay the code.
#
# ***Question 3*** : How can missing or inaccurate data affect data analysis and decision-making?
#
# - It leads to biased and erroneous results, causing poor business decisions based on incorrect information.

# %% [markdown]
# **GitHub Repo**:
#  https://github.com/felopoateer/github-analysis-project
